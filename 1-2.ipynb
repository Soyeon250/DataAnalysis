# %% [markdown]
# <a href="https://colab.research.google.com/github/Soyeon250/DataAnalysis/blob/main/1-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def get_year_months():
  year_months = []
  for year in range(2015, 2024+1):
    for month in range(1, 12+1):
      year_months.append(f'{year}{month:02d}')
  return year_months

result_data = []

api_key = "5a4e4156566c737935305568525850"

for year_month in get_year_months():
    year = year_month[:4]
    month = year_month[4:]
    url = f"http://openapi.seoul.go.kr:8088/{api_key}/json/energyUseDataSummaryInfo/1/1000/{year}/{month}"

    response = requests.get(url)

    if response.status_code == 200:
        print("api 호출 성공")
        data = response.json()

        if 'energyUseDataSummaryInfo' in data:
            if 'row' in data['energyUseDataSummaryInfo']:
              rows = data['energyUseDataSummaryInfo']['row']

            for item in rows:
              if item.get('MM_TYPE') == '개인':

                  energy_data = {
                      '전기': item.get('EUS'),
                      '가스': item.get('GUS'),
                      '수도': item.get('WUS'),
                      '지역난방': item.get('HUS')
                  }
                  result_data.append(energy_data)
                  print(energy_data)

    else:
        print(f"API 호출 실패: {response.status_code}")
# Out:
# api 호출 성공
# {'전기': '193784708', '가스': '59133720', '수도': '12819757.886', '지역난방': '22740838.937'}
# api 호출 성공
# {'전기': '189974230', '가스': '56487358', '수도': '12656888.218', '지역난방': '18793320.213'}
# api 호출 성공
# {'전기': '175215719', '가스': '49984873', '수도': '12655474.249', '지역난방': '13826348.508'}
# api 호출 성공
# {'전기': '183891769', '가스': '37306841', '수도': '12954773.246', '지역난방': '5836002.885'}
# api 호출 성공
# {'전기': '177289769', '가스': '22060892', '수도': '13086734.214', '지역난방': '1320895.801'}
# api 호출 성공
# {'전기': '186073153', '가스': '12677645', '수도': '14241651.402', '지역난방': '294312.634'}
# api 호출 성공
# {'전기': '165114568', '가스': '8893640', '수도': '12083879.038', '지역난방': '702863.645'}
# api 호출 성공
# {'전기': '242000479', '가스': '7619018', '수도': '15164553.742', '지역난방': '460288.965'}
# api 호출 성공
# {'전기': '207540868', '가스': '6518422', '수도': '14419078.727', '지역난방': '305710.728'}
# api 호출 성공
# {'전기': '186473958', '가스': '8924018', '수도': '14711828.766', '지역난방': '3167520.127'}
# api 호출 성공
# {'전기': '196892030', '가스': '20322557', '수도': '13692668.676', '지역난방': '11210982.51'}
# api 호출 성공
# {'전기': '203388142', '가스': '40095231', '수도': '13904162.958', '지역난방': '21102616.717'}
# api 호출 성공
# {'전기': '215330620', '가스': '57641741', '수도': '13218916.436', '지역난방': '27186166.133'}
# api 호출 성공
# {'전기': '216677664', '가스': '68879796', '수도': '13312113.622', '지역난방': '21452994.715'}
# api 호출 성공
# {'전기': '203451798', '가스': '60019600', '수도': '13191615.499', '지역난방': '14070182.978'}
# api 호출 성공
# {'전기': '202541336', '가스': '40370608', '수도': '13748935.736', '지역난방': '4556396.936'}
# api 호출 성공
# {'전기': '195448592', '가스': '23077064', '수도': '13762618.524', '지역난방': '1166907.615'}
# api 호출 성공
# {'전기': '205061790', '가스': '13344932', '수도': '14543461.284', '지역난방': '340601.066'}
# api 호출 성공
# {'전기': '226567751', '가스': '9641899', '수도': '14686067.972', '지역난방': '89835.795'}
# api 호출 성공
# {'전기': '303032015', '가스': '8324791', '수도': '15442898.396', '지역난방': '27303.979'}
# api 호출 성공
# {'전기': '241676328', '가스': '7030657', '수도': '15233262.266', '지역난방': '2597269.386'}
# api 호출 성공
# {'전기': '197827666', '가스': '10129547', '수도': '15173666.268', '지역난방': '2142328.405'}
# api 호출 성공
# {'전기': '204812090', '가스': '23915383', '수도': '7215169', '지역난방': '10865402.481'}
# api 호출 성공
# {'전기': '212192127', '가스': '46917377', '수도': '14415082.726', '지역난방': '17554645.961'}
# api 호출 성공
# {'전기': '222980440', '가스': '61781772', '수도': '14077034.016', '지역난방': '20567265.356'}
# api 호출 성공
# {'전기': '226181991', '가스': '73537514', '수도': '13724166.552', '지역난방': '17733782.246'}
# api 호출 성공
# {'전기': '208386870', '가스': '64297007', '수도': '13598081.92', '지역난방': '11477962.549'}
# api 호출 성공
# {'전기': '214202199', '가스': '45050211', '수도': '12690616.841', '지역난방': '4466510.567'}
# api 호출 성공
# {'전기': '209894672', '가스': '25103152', '수도': '12950202.184', '지역난방': '19809726.81'}
# api 호출 성공
# {'전기': '211179181', '가스': '14312533', '수도': '13629782.778', '지역난방': '235859.209'}
# api 호출 성공
# {'전기': '255974689', '가스': '10085989', '수도': '13786672.672', '지역난방': '40992.123'}
# api 호출 성공
# {'전기': '297850172', '가스': '8429188', '수도': '14291829.084', '지역난방': '118927.011'}
# api 호출 성공
# {'전기': '232360099', '가스': '8981707', '수도': '13842675.562', '지역난방': '1279967.753'}
# api 호출 성공
# {'전기': '202205893', '가스': '11910453', '수도': '13811362.596', '지역난방': '2177857.689'}
# api 호출 성공
# {'전기': '215620132', '가스': '26041170', '수도': '13268391.686', '지역난방': '12290667.843'}
# api 호출 성공
# {'전기': '228503347', '가스': '59466188', '수도': '13243386.284', '지역난방': '21819495.238'}
# api 호출 성공
# {'전기': '208518118', '가스': '82250572', '수도': '10997016.858', '지역난방': '15268708.539'}
# api 호출 성공
# {'전기': '243271752', '가스': '88496947', '수도': '12905042.86', '지역난방': '22671708.494'}
# api 호출 성공
# {'전기': '219203768', '가스': '73426397', '수도': '12769174.532', '지역난방': '10924939.951'}
# api 호출 성공
# {'전기': '222416406', '가스': '42565583', '수도': '13280372.714', '지역난방': '5017072.364'}
# api 호출 성공
# {'전기': '213539965', '가스': '29234091', '수도': '13181988.612', '지역난방': '1375720.246'}
# api 호출 성공
# {'전기': '222820943', '가스': '17132065', '수도': '14051336.092', '지역난방': '285820.628'}
# api 호출 성공
# {'전기': '269705511', '가스': '11259835', '수도': '14333667.052', '지역난방': '25843523.832'}
# api 호출 성공
# {'전기': '393315950', '가스': '8166455', '수도': '14956551.722', '지역난방': '15855.507'}
# api 호출 성공
# {'전기': '267255459', '가스': '7210123', '수도': '14705302.054', '지역난방': '192778.954'}
# api 호출 성공
# {'전기': '217274530', '가스': '14102506', '수도': '14728158.238', '지역난방': '4137960.203'}
# api 호출 성공
# {'전기': '227294230', '가스': '31239511', '수도': '13706690.088', '지역난방': '10276290.855'}
# api 호출 성공
# {'전기': '238692561', '가스': '54019855', '수도': '13732488.456', '지역난방': '20421845.603'}
# api 호출 성공
# {'전기': '253600219', '가스': '80308239', '수도': '13442971.1', '지역난방': '21963093.848'}
# api 호출 성공
# {'전기': '244927344', '가스': '81902188', '수도': '13495213.9', '지역난방': '106134923.132'}
# api 호출 성공
# {'전기': '223736787', '가스': '65146586.443', '수도': '13167550', '지역난방': '13194262.09'}
# api 호출 성공
# {'전기': '232166121', '가스': '49391508', '수도': '13753270.8', '지역난방': '7858587.747'}
# api 호출 성공
# {'전기': '221753919', '가스': '31370114', '수도': '13610225.3', '지역난방': '1442006.927'}
# api 호출 성공
# {'전기': '226119779', '가스': '15771701', '수도': '14223536.4', '지역난방': '331690.945'}
# api 호출 성공
# {'전기': '257854441', '가스': '10700835', '수도': '14451345.9', '지역난방': '968957.161'}
# api 호출 성공
# {'전기': '342924356', '가스': '8884580', '수도': '15115644.2', '지역난방': '147683.081'}
# api 호출 성공
# {'전기': '275890739', '가스': '8397984', '수도': '14472395.4', '지역난방': '2292916.674'}
# api 호출 성공
# {'전기': '228095713', '가스': '11876816', '수도': '14804362.3', '지역난방': '2590192.143'}
# api 호출 성공
# {'전기': '231283724', '가스': '24835894', '수도': '14123043.9', '지역난방': '14983364.884'}
# api 호출 성공
# {'전기': '244976724', '가스': '54509050', '수도': '14184785.2', '지역난방': '23558262.283'}
# api 호출 성공
# {'전기': '258045023', '가스': '74543710', '수도': '13737344.7', '지역난방': '24876689.382'}
# api 호출 성공
# {'전기': '254879033', '가스': '76363768', '수도': '14052828.8', '지역난방': '20848668.612'}
# api 호출 성공
# {'전기': '244369714', '가스': '64367515', '수도': '13841531', '지역난방': '14194450.151'}
# api 호출 성공
# {'전기': '247831442', '가스': '48373693', '수도': '14618775.2', '지역난방': '8499792.566'}
# api 호출 성공
# {'전기': '237473019', '가스': '33564967', '수도': '14679505.8', '지역난방': '3702573.787'}
# api 호출 성공
# {'전기': '255905483', '가스': '18132779', '수도': '15240275.9', '지역난방': '705948.444'}
# api 호출 성공
# {'전기': '267363208', '가스': '10708959', '수도': '15033682.8', '지역난방': '21617947.477'}
# api 호출 성공
# {'전기': '320723239', '가스': '10177428', '수도': '15600097.8', '지역난방': '286814.663'}
# api 호출 성공
# {'전기': '309166830', '가스': '8026967', '수도': '15232496.1', '지역난방': '301630.266'}
# api 호출 성공
# {'전기': '239397195', '가스': '16322881', '수도': '15641048.9', '지역난방': '4581073.913'}
# api 호출 성공
# {'전기': '247308528', '가스': '30095679', '수도': '14835013.9', '지역난방': '12882737.572'}
# api 호출 성공
# {'전기': '265370372', '가스': '51095720', '수도': '15036546.3', '지역난방': '26512966.052'}
# api 호출 성공
# {'전기': '287882528', '가스': '80955422', '수도': '14273105.8', '지역난방': '31069705.783'}
# api 호출 성공
# {'전기': '271224712', '가스': '85581769', '수도': '13679936.9', '지역난방': '22238103.26'}
# api 호출 성공
# {'전기': '243868926', '가스': '67363697', '수도': '14263783.7', '지역난방': '12528828.427'}
# api 호출 성공
# {'전기': '248131327', '가스': '43591034', '수도': '14570687.2', '지역난방': '5220678.501'}
# api 호출 성공
# {'전기': '241741576', '가스': '24638403', '수도': '14312460.916', '지역난방': '2246730.037'}
# api 호출 성공
# {'전기': '254958704', '가스': '18898880', '수도': '15174790.6', '지역난방': '396903.273'}
# api 호출 성공
# {'전기': '334733756', '가스': '9631171', '수도': '16619105.064', '지역난방': '5529269.058'}
# api 호출 성공
# {'전기': '409719040', '가스': '10205066', '수도': '15737994.8', '지역난방': '127607.838'}
# api 호출 성공
# {'전기': '290606638', '가스': '6602872', '수도': '15497783.9', '지역난방': '159066.058'}
# api 호출 성공
# {'전기': '253845816', '가스': '13840155', '수도': '15930639.8', '지역난방': '4220985.501'}
# api 호출 성공
# {'전기': '255516339', '가스': '28571168', '수도': '14975050.4', '지역난방': '13463697.643'}
# api 호출 성공
# {'전기': '265314948', '가스': '54651317', '수도': '14873728.5', '지역난방': '25989752.285'}
# api 호출 성공
# {'전기': '286037593', '가스': '80605997', '수도': '14303008.9', '지역난방': '30320240.229'}
# api 호출 성공
# {'전기': '279071999', '가스': '90004956', '수도': '14437161.1', '지역난방': '27615965.122'}
# api 호출 성공
# {'전기': '256771728', '가스': '75577723', '수도': '14181287.1', '지역난방': '15843818.715'}
# api 호출 성공
# {'전기': '255028242', '가스': '49843915.6', '수도': '14443060.3', '지역난방': '5725570.382'}
# api 호출 성공
# {'전기': '238866649', '가스': '28185559', '수도': '14344240.1', '지역난방': '1457446.39'}
# api 호출 성공
# {'전기': '254486733', '가스': '15468022', '수도': '15087457.3', '지역난방': '838539.99'}
# api 호출 성공
# {'전기': '336383318', '가스': '10701998', '수도': '14907198', '지역난방': '50033.827'}
# api 호출 성공
# {'전기': '382965547', '가스': '8718677', '수도': '15555926.8', '지역난방': '3278812.728'}
# api 호출 성공
# {'전기': '294121752', '가스': '9220604.8', '수도': '15016541.4', '지역난방': '7221052.414'}
# api 호출 성공
# {'전기': '250724946', '가스': '13803068', '수도': '14983916.7', '지역난방': '5216710.607'}
# api 호출 성공
# {'전기': '252081207', '가스': '28471902', '수도': '14485236.6', '지역난방': '10685943.786'}
# api 호출 성공
# {'전기': '266989892', '가스': '52230601', '수도': '14538742.5', '지역난방': '31655489.658'}
# api 호출 성공
# {'전기': '286485085', '가스': '82529062', '수도': '14466145', '지역난방': '29668211.872'}
# api 호출 성공
# {'전기': '272702468', '가스': '82851936', '수도': '14516011.2', '지역난방': '20320092.953'}
# api 호출 성공
# {'전기': '243877178', '가스': '62656340', '수도': '13506311.3', '지역난방': '10516665.902'}
# api 호출 성공
# {'전기': '247142965', '가스': '38484227', '수도': '13951884.7', '지역난방': '4292056.162'}
# api 호출 성공
# {'전기': '241448830', '가스': '25601698', '수도': '13928576.1', '지역난방': '1354710.378'}
# api 호출 성공
# {'전기': '259143276', '가스': '14742811', '수도': '14822130.1', '지역난방': '1169879.028'}
# api 호출 성공
# {'전기': '328201532', '가스': '9760384', '수도': '14673620.5', '지역난방': '2659009.06'}
# api 호출 성공
# {'전기': '407479395', '가스': '8486915', '수도': '15402396.8', '지역난방': '530124.99'}
# api 호출 성공
# {'전기': '332452167', '가스': '7674573', '수도': '14941654.4', '지역난방': '19457189.828'}
# api 호출 성공
# {'전기': '255560826', '가스': '11273798', '수도': '14918622.9', '지역난방': '3049594.261'}
# api 호출 성공
# {'전기': '255362764', '가스': '23749738', '수도': '14439208.8', '지역난방': '13225464.736'}
# api 호출 성공
# {'전기': '271015225', '가스': '47560201', '수도': '14519931.6', '지역난방': '24169250.596'}
# api 호출 성공
# {'전기': '290223476', '가스': '65608930', '수도': '14119336.8', '지역난방': '26759601.094'}
# api 호출 성공
# {'전기': '280810330', '가스': '65184440', '수도': '14247296.7', '지역난방': '18696968.203'}
# api 호출 성공
# {'전기': '259332255', '가스': '58563376', '수도': '13792441.8', '지역난방': '13455710.256'}
# api 호출 성공
# {'전기': '256332884', '가스': '35786315', '수도': '14330249.1', '지역난방': '3099650.225'}
# api 호출 성공
# {'전기': '244740675', '가스': '18077028', '수도': '14158142.9', '지역난방': '28333197.76'}
# api 호출 성공
# {'전기': '270158916', '가스': '11903071', '수도': '14966075.6', '지역난방': '20226852.923'}
# api 호출 성공
# {'전기': '340000663', '가스': '8319412', '수도': '14992942.2', '지역난방': '2173041.617'}
# api 호출 성공
# {'전기': '463971328', '가스': '7072251', '수도': '15873544.6', '지역난방': '130082.263'}
# api 호출 성공
# {'전기': '409872908', '가스': '5729131', '수도': '15143321.6', '지역난방': '3420507.136'}
# api 호출 성공
# {'전기': '282268119', '가스': '8233421', '수도': '15297669.9', '지역난방': '2695491.396'}
# api 호출 성공
# {'전기': '257927956', '가스': '17418221', '수도': '14678672.5', '지역난방': '8836296.454'}
# api 호출 성공
# {'전기': '134828126', '가스': '42103424', '수도': '7326853.6', '지역난방': '1513199.277'}

# %%
import requests

api_key = "5a4e4156566c737935305568525850"
url = f"http://openapi.seoul.go.kr:8088/{api_key}/json/energyUseDataSummaryInfo/1/5/2015/01"

response = requests.get(url)

if response.status_code == 200:
    print("api 호출 성공")
    print(response.json())
else:
    print(f"API 호출 실패: {response.status_code}")
# Out:
# api 호출 성공
# {'energyUseDataSummaryInfo': {'list_total_count': 7, 'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'}, 'row': [{'YEAR': '2015', 'MON': '01', 'MM_TYPE': '개인', 'CNT': '767791', 'EUS': '193784708', 'EUS1': '194781915', 'EUS2': '204969429', 'ECO2_1': '-6090964', 'ECO2_2': '-2582568.736', 'GUS': '59133720', 'GUS1': '57163993', 'GUS2': '68297619', 'GCO2_1': '-3597086', 'GCO2_2': '-8057472.64', 'WUS': '12819757.886', 'WUS1': '12723680.426', 'WUS2': '12899476.73', 'WCO2_1': '8179.308', 'WCO2_2': '2715.530256', 'HUS': '22740838.937', 'HUS1': '23400055.303', 'HUS2': '27090493.875', 'HCO2_1': '-2504435.652', 'HCO2_2': '-33660084.213069', 'REG_DATE': '2015-06-04 17:03:55.0'}, {'YEAR': '2015', 'MON': '01', 'MM_TYPE': '학교', 'CNT': '1382', 'EUS': '134955565', 'EUS1': '128707423', 'EUS2': '145561511', 'ECO2_1': '-2178902', 'ECO2_2': '-923854.448', 'GUS': '9107197', 'GUS1': '8410968', 'GUS2': '10745416', 'GCO2_1': '-470995', 'GCO2_2': '-1055028.8', 'WUS': '2075819.2', 'WUS1': '2097433.8', 'WUS2': '2133200.8', 'WCO2_1': '-39498.1', 'WCO2_2': '-13113.3692', 'HUS': '0', 'HUS1': '0', 'HUS2': '0', 'HCO2_1': '0', 'HCO2_2': '0', 'REG_DATE': '2015-06-04 17:03:55.0'}, {'YEAR': '2015', 'MON': '01', 'MM_TYPE': '종교단체', 'CNT': '32', 'EUS': '372270', 'EUS1': '363376', 'EUS2': '411363', 'ECO2_1': '-15099.5', 'ECO2_2': '-6402.188', 'GUS': '53331', 'GUS1': '45727', 'GUS2': '63312', 'GCO2_1': '-1188.5', 'GCO2_2': '-2662.24', 'WUS': '5945', 'WUS1': '4548', 'WUS2': '4519', 'WCO2_1': '1411.5', 'WCO2_2': '468.618', 'HUS': '0', 'HUS1': '0', 'HUS2': '0', 'HCO2_1': '0', 'HCO2_2': '0', 'REG_DATE': '2015-06-04 17:03:55.0'}, {'YEAR': '2015', 'MON': '01', 'MM_TYPE': '소상공인', 'CNT': '2058', 'EUS': '10249618', 'EUS1': '9927610', 'EUS2': '11039593', 'ECO2_1': '-233983.5', 'ECO2_2': '-99209.004', 'GUS': '536119', 'GUS1': '523810', 'GUS2': '642921', 'GCO2_1': '-47246.5', 'GCO2_2': '-105832.16', 'WUS': '147273', 'WUS1': '146480.6', 'WUS2': '147325.6', 'WCO2_1': '369.9', 'WCO2_2': '122.8068', 'HUS': '0', 'HUS1': '0', 'HUS2': '0', 'HCO2_1': '0', 'HCO2_2': '0', 'REG_DATE': '2015-06-04 17:03:55.0'}, {'YEAR': '2015', 'MON': '01', 'MM_TYPE': '공동주택관리소', 'CNT': '1747', 'EUS': '327102096', 'EUS1': '329852334', 'EUS2': '351694752', 'ECO2_1': '-13671447', 'ECO2_2': '-5796693.528', 'GUS': '22834274', 'GUS1': '21141017', 'GUS2': '25338506', 'GCO2_1': '-405487.5', 'GCO2_2': '-908292', 'WUS': '12844807.5', 'WUS1': '12763070', 'WUS2': '12979835.8', 'WCO2_1': '-26645.4', 'WCO2_2': '-8846.2728', 'HUS': '0', 'HUS1': '0', 'HUS2': '0', 'HCO2_1': '0', 'HCO2_2': '0', 'REG_DATE': '2015-06-04 17:03:55.0'}]}}
